# %%
try:
  n=int(input("enter a number:"))
  print("you entered:",n)
except ValueError:
  print("not a valid number")
# Out:
# enter a number:d
# not a valid number

# %%
try:
  num=int(input("enter a number to divide 100:"))
  result=100/num
except ZeroDivisionError:
  print("cannot dividie by zero")
except ValueError:
  print("you entered invalid number")
else:
  print(result)
finally:
  print("completed execution")
# Out:
# enter a number to divide 100:g
# you entered invalid number
# completed execution

# %%
try:
  a=int("one")
  b=10/0
except (ValueError,ZeroDivisionError) as e:
  print("error occurred",e)
# Out:
# error occurred division by zero

# %%
def age_check(age):
  if age<0:
    raise ValueError("age cant be negative")
  else:
    print("valid age")

try:
  age_check(-20)
except ValueError as e:
  print("error:",e)



      target=device_type
    'value':random.uniform(*READING_RANGES[target])
# Out:
# error: age cant be negative

# %%
import datetime
import random
from collections import namedtuple

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
for i in range(0,101):
  #sensor = namedtuple('sensor', ['timestamp_str', 'device_id', 'device_type', 'location', 'value'])
  sensor = namedtuple('sensor', ['device_id', 'device_type', 'location',])
  random_data = {
      'device_id': random.randint(0, 101),
      'device_type':random.choice(DEVICE_TYPES),
      'location': random.choice(LOCATIONS)
      }
  print(sensor(**random_data))
# Out:
# sensor(device_id=50, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=90, device_type='Temperature_Sensor', location='OfficeB')
# sensor(device_id=34, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=23, device_type='Light_Sensor', location='Warehouse')
# sensor(device_id=17, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=90, device_type='Light_Sensor', location='Lab2')
# sensor(device_id=87, device_type='Pressure_Sensor', location='OfficeA')
# sensor(device_id=41, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=85, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=92, device_type='Pressure_Sensor', location='OfficeA')
# sensor(device_id=74, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=18, device_type='Humidity_Sensor', location='OfficeA')
# sensor(device_id=89, device_type='Light_Sensor', location='OfficeA')
# sensor(device_id=72, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=76, device_type='Humidity_Sensor', location='OfficeB')
# sensor(device_id=70, device_type='Humidity_Sensor', location='Lab1')
# sensor(device_id=0, device_type='Humidity_Sensor', location='Lab1')
# sensor(device_id=18, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=78, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=69, device_type='Temperature_Sensor', location='Lab2')
# sensor(device_id=27, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=61, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=20, device_type='Light_Sensor', location='OfficeB')
# sensor(device_id=43, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=6, device_type='Temperature_Sensor', location='Warehouse')
# sensor(device_id=56, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=92, device_type='Temperature_Sensor', location='Warehouse')
# sensor(device_id=25, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=8, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=99, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=33, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=73, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=39, device_type='Pressure_Sensor', location='OfficeA')
# sensor(device_id=72, device_type='Light_Sensor', location='OfficeB')
# sensor(device_id=9, device_type='Light_Sensor', location='OfficeA')
# sensor(device_id=50, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=26, device_type='Temperature_Sensor', location='Warehouse')
# sensor(device_id=59, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=92, device_type='Pressure_Sensor', location='Warehouse')
# sensor(device_id=29, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=8, device_type='Pressure_Sensor', location='Warehouse')
# sensor(device_id=20, device_type='Temperature_Sensor', location='Lab1')
# sensor(device_id=101, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=46, device_type='Temperature_Sensor', location='Warehouse')
# sensor(device_id=21, device_type='Light_Sensor', location='OfficeB')
# sensor(device_id=68, device_type='Pressure_Sensor', location='OfficeA')
# sensor(device_id=90, device_type='Humidity_Sensor', location='Lab1')
# sensor(device_id=68, device_type='Light_Sensor', location='Warehouse')
# sensor(device_id=65, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=32, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=51, device_type='Humidity_Sensor', location='OfficeB')
# sensor(device_id=8, device_type='Pressure_Sensor', location='OfficeA')
# sensor(device_id=63, device_type='Temperature_Sensor', location='Lab2')
# sensor(device_id=50, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=76, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=78, device_type='Humidity_Sensor', location='Lab1')
# sensor(device_id=25, device_type='Light_Sensor', location='OfficeA')
# sensor(device_id=14, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=8, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=95, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=25, device_type='Light_Sensor', location='Warehouse')
# sensor(device_id=48, device_type='Humidity_Sensor', location='OfficeB')
# sensor(device_id=64, device_type='Pressure_Sensor', location='Warehouse')
# sensor(device_id=42, device_type='Light_Sensor', location='Lab2')
# sensor(device_id=96, device_type='Light_Sensor', location='OfficeA')
# sensor(device_id=33, device_type='Light_Sensor', location='OfficeA')
# sensor(device_id=45, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=101, device_type='Temperature_Sensor', location='Lab1')
# sensor(device_id=100, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=6, device_type='Humidity_Sensor', location='Warehouse')
# sensor(device_id=10, device_type='Light_Sensor', location='Lab2')
# sensor(device_id=77, device_type='Temperature_Sensor', location='OfficeB')
# sensor(device_id=3, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=83, device_type='Humidity_Sensor', location='OfficeA')
# sensor(device_id=3, device_type='Humidity_Sensor', location='OfficeB')
# sensor(device_id=75, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=85, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=41, device_type='Pressure_Sensor', location='OfficeB')
# sensor(device_id=36, device_type='Humidity_Sensor', location='OfficeB')
# sensor(device_id=5, device_type='Temperature_Sensor', location='Lab1')
# sensor(device_id=63, device_type='Humidity_Sensor', location='Lab2')
# sensor(device_id=32, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=91, device_type='Light_Sensor', location='Lab2')
# sensor(device_id=9, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=21, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=67, device_type='Pressure_Sensor', location='Lab1')
# sensor(device_id=32, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=38, device_type='Pressure_Sensor', location='Warehouse')
# sensor(device_id=12, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=59, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=71, device_type='Pressure_Sensor', location='Warehouse')
# sensor(device_id=100, device_type='Pressure_Sensor', location='Lab2')
# sensor(device_id=7, device_type='Light_Sensor', location='Lab1')
# sensor(device_id=78, device_type='Light_Sensor', location='Warehouse')
# sensor(device_id=96, device_type='Humidity_Sensor', location='Lab2')
# sensor(device_id=88, device_type='Temperature_Sensor', location='Lab1')
# sensor(device_id=46, device_type='Temperature_Sensor', location='OfficeA')
# sensor(device_id=82, device_type='Light_Sensor', location='Warehouse')
# sensor(device_id=36, device_type='Temperature_Sensor', location='Warehouse')
# sensor(device_id=1, device_type='Temperature_Sensor', location='OfficeB')
# sensor(device_id=36, device_type='Temperature_Sensor', location='Warehouse')

# %%
import random
from datetime import datetime, timedelta

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),   # Celsius
    'Humidity_Sensor': (30.0, 80.0),      # Percentage
    'Pressure_Sensor': (980.0, 1030.0),   # hPa
    'Light_Sensor': (100, 1000)           # Lux
}

print("\n--- Task 1: Data Generation and Basic Structures ---")

raw_sensor_data = []

# Starting timestamp
start_time = datetime.now()

for i in range(100):
    timestamp = (start_time + timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:100]:
    print(reading)
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-20 09:08:52', 'DEV001', 'Pressure_Sensor', 'Lab1', 1005.38)
